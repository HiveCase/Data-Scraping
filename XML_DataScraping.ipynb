# %% [markdown]
# <a href="https://colab.research.google.com/github/HiveCase/Data-Scraping/blob/main/XML_DataScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Grants released to national sports championships from 2012-2015

# %%
import pandas as pd
data = pd.read_xml('datafile.xml')

# %%
data.head()
# Out:
#    S._NO                           NAME_OF_THE_FEDERATION  _2012-13  _2013-14  \
# 0      1          Athletics Federation of India New Delhi      4.00       NaN
# 1      2           Archery Association of India New Delhi      1.92       NaN
# 2      3      All    India    Chess    Federation Chennai     11.75       9.5
# 3      4                         Judo Federation of India      6.50      14.5
# 4      5  Rowing    Federation    of   India Secunderabad     13.00      10.5
#
#    _2014-15  TOTAL
# 0       1.5   5.50
# 1       NaN   1.92
# 2       1.5  22.75
# 3       6.4  27.40
# 4       5.5  29.00

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=data)
# Out:
# https://docs.google.com/spreadsheets/d/1pZSDlwp0r5zr8_9I-leYKv6NFOUi8xR8QEYeW8X3acQ#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1pZSDlwp0r5zr8_9I-leYKv6NFOUi8xR8QEYeW8X3acQ#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse("datafile.xml")
tree

# %%
root = tree.getroot()
root
# Out:
# <Element 'DATASET' at 0x782c6dbee0c0>

# %%
len(root)
# Out:
# 44

# %%
root[1]
# Out:
# <Element 'ROW2' at 0x782c6dbee390>

# %%
root.findall('ROW1')
# Out:
# [<Element 'ROW1' at 0x782c6dbee110>]

# %%
root[1][1].text
# Out:
# 'Archery Association of India New Delhi'

# %%
root[1][0]
# Out:
# <Element 'S._NO' at 0x782c6dbee3e0>

# %%
root[1][0].text
# Out:
# '2'

# %%
root[2][1].tag
# Out:
# 'NAME_OF_THE_FEDERATION'

# %%
root[2][1].text
# Out:
# 'All    India    Chess    Federation Chennai'

# %%
for i in range(44):
  print(root[i][1].text,":",root[i][5].text)
# Out:
# Athletics Federation of India New Delhi : 5.5
# Archery Association of India New Delhi : 1.92
# All    India    Chess    Federation Chennai : 22.75
# Judo Federation of India : 27.4
# Rowing    Federation    of   India Secunderabad : 29
# Table Tennis Federation of India New Delhi : 35.38
# Swimming  Federation  of  India Ahmadabad : 28
# Indian         Amateur         Boxing Federation New Delhi : 16.25
# Indian  Weightlifting  Federation New Delhi : 26.66
# Badminton Association of India : 18
# Equestrian  Federation  of  India New Delhi : 6
# Indian Golf Union New Delhi : 8.76
# Wrestling   Federation   of  India I.G. Stadium Delhi : 25.5
# Indian        Amateur        Kabaddi Federation Jaipur : 26.69
# Volleyball  Federation  of  India Chennai : 26.75
# Amateur  Handball  Federation  J & K : 39.98
# Fencing   Association   of   India Patiala : 10.5
# Indian   Kayaking   &   Canoeing Association New Delhi : 25.25
# Special   Olympic   Bharat   New Delhi : 16.5
# ...

# %%
df = pd.DataFrame([[data.text for data in node] for node in root],columns =['','Sl.No','NAME_OF_THE_FEDERATION','2012-13','2013-14','2014-15'])
df = df.iloc[:,1:]
df
# Out:
#                                                 Sl.No NAME_OF_THE_FEDERATION  \
# 0             Athletics Federation of India New Delhi                      4
# 1              Archery Association of India New Delhi                   1.92
# 2         All    India    Chess    Federation Chennai                  11.75
# 3                            Judo Federation of India                    6.5
# 4     Rowing    Federation    of   India Secunderabad                     13
# 5          Table Tennis Federation of India New Delhi                   13.5
# 6           Swimming  Federation  of  India Ahmadabad                   11.5
# 7   Indian         Amateur         Boxing Federati...                  16.25
# 8         Indian  Weightlifting  Federation New Delhi                  12.16
# 9                      Badminton Association of India                     NA
# 10        Equestrian  Federation  of  India New Delhi                    1.5
# ...
